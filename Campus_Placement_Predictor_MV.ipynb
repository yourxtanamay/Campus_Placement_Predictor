# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline   # for jupyter notebook ----> figures to output in cell instead of opened as new page

# %%
df = pd.read_csv("C:\\Users\\Tanmay Paul\\Placement_Data_Full_Class.csv")
df.head(2)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  degree_t  \
# 0      1      M  67.00   Others  91.00  Others  Commerce     58.00  Sci&Tech
# 1      2      M  79.33  Central  78.33  Others   Science     77.48  Sci&Tech
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR  58.80  Placed  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0

# %%
df=df.set_index('sl_no')
df.head(2)
# Out:
#       gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  degree_t  \
# sl_no
# 1          M  67.00   Others  91.00  Others  Commerce     58.00  Sci&Tech
# 2          M  79.33  Central  78.33  Others   Science     77.48  Sci&Tech
#
#       workex  etest_p specialisation  mba_p  status    salary
# sl_no
# 1         No     55.0         Mkt&HR  58.80  Placed  270000.0
# 2        Yes     86.5        Mkt&Fin  66.28  Placed  200000.0

# %%
# df=df.rename(columns={'ssc_b':'ssc_board','hsc_b':'hsc_board','hsc_s':'hsc','degree_t':'degree_type','workex':'work_experience'})

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 215 entries, 1 to 215
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gender          215 non-null    str
#  1   ssc_p           215 non-null    float64
#  2   ssc_b           215 non-null    str
#  3   hsc_p           215 non-null    float64
#  4   hsc_b           215 non-null    str
#  5   hsc_s           215 non-null    str
#  6   degree_p        215 non-null    float64
#  7   degree_t        215 non-null    str
#  8   workex          215 non-null    str
#  9   etest_p         215 non-null    float64
#  10  specialisation  215 non-null    str
#  11  mba_p           215 non-null    float64
#  12  status          215 non-null    str
#  13  salary          148 non-null    float64
# dtypes: float64(6), str(8)
# memory usage: 23.6 KB

# %%
df.describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
df.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status',
#        'salary'],
#       dtype='str')

# %%
catvars = []
numvars = []

for col in df.columns:
    if df[col].dtype == 'object':
        catvars.append(col)
    else:
        numvars.append(col)

print(catvars, numvars)
# Out:
# [] ['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status', 'salary']

# %%
df.isnull().sum()
# Out:
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# ### Handling Null values

# %%
df.shape
# Out:
# (215, 14)

# %%
def plotdistplot(col):

    plt.figure(figsize=(15,7))
    sn.distplot(df['salary'],kde=True,hist=False,label='Actual Salary',color='orange')
    sn.distplot(df[col],kde=True,hist=False,label=col,color='black')

# %%
# df['salary'].value_counts()
# dict(df['salary'].value_counts())

# %%
mostfreq = list(dict(df['salary'].value_counts()).items())[0]
mostfreq
# Out:
# (300000.0, np.int64(22))

# %%
print(df['salary'].mode())
print(df['salary'].median())
print(df['salary'].mean())
# Out:
# 0    300000.0
# Name: salary, dtype: float64
# 265000.0
# 288655.4054054054

# %%
df['salary'].mean()  # average salary
# Out:
# np.float64(288655.4054054054)

# %%
df['salary_mean'] = df['salary'].fillna(df['salary'].mean())
df['salary_median'] = df['salary'].fillna(df['salary'].median())
df['salary_mode'] = df['salary'].fillna(df['salary'].mode()[0])
df.head()
# Out:
#       gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# sl_no
# 1          M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 2          M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 3          M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4          M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 5          M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#       workex  etest_p specialisation  mba_p      status    salary  \
# sl_no
# 1         No     55.0         Mkt&HR  58.80      Placed  270000.0
# 2        Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 3         No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 4         No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 5         No     96.8        Mkt&Fin  55.50      Placed  425000.0
#
#          salary_mean  salary_median  salary_mode
# sl_no
# 1      270000.000000       270000.0     270000.0
# 2      200000.000000       200000.0     200000.0
# 3      250000.000000       250000.0     250000.0
# 4      288655.405405       265000.0     300000.0
# 5      425000.000000       425000.0     425000.0

# %%
sallist = ['salary_mean','salary_median','salary_mode']
for sal in sallist:
    plotdistplot(sal)
# Out:
# C:\Users\Tanmay Paul\AppData\Local\Temp\ipykernel_5368\359303696.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['salary'],kde=True,hist=False,label='Actual Salary',color='orange')
# C:\Users\Tanmay Paul\AppData\Local\Temp\ipykernel_5368\359303696.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],kde=True,hist=False,label=col,color='black')
# C:\Users\Tanmay Paul\AppData\Local\Temp\ipykernel_5368\359303696.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['salary'],kde=True,hist=False,label='Actual Salary',color='orange')
# C:\Users\Tanmay Paul\AppData\Local\Temp\ipykernel_5368\359303696.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],kde=True,hist=False,label=col,color='black')
# C:\Users\Tanmay Paul\AppData\Local\Temp\ipykernel_5368\359303696.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['salary'],kde=True,hist=False,label='Actual Salary',color='orange')
# C:\Users\Tanmay Paul\AppData\Local\Temp\ipykernel_5368\359303696.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col],kde=True,hist=False,label=col,color='black')

# %%
# filling the salary with mean

df['salary'] = df['salary'].fillna(df['salary'].mean())
df.head()
# Out:
#       gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# sl_no
# 1          M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 2          M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 3          M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4          M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 5          M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#       workex  etest_p specialisation  mba_p      status         salary  \
# sl_no
# 1         No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 2        Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 3         No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 4         No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 5         No     96.8        Mkt&Fin  55.50      Placed  425000.000000
#
#          salary_mean  salary_median  salary_mode
# sl_no
# 1      270000.000000       270000.0     270000.0
# 2      200000.000000       200000.0     200000.0
# 3      250000.000000       250000.0     250000.0
# 4      288655.405405       265000.0     300000.0
# 5      425000.000000       425000.0     425000.0

# %%
df = df.drop(columns=['salary_mean', 'salary_median', 'salary_mode'])
df.isnull().sum()
# Out:
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
df
# Out:
#       gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# sl_no
# 1          M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 2          M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 3          M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4          M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 5          M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ...      ...    ...      ...    ...      ...       ...       ...        ...
# 211        M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 212        M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 213        M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 214        F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 215        M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#       workex  etest_p specialisation  mba_p      status         salary
# sl_no
# 1         No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 2        Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 3         No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 4         No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 5         No     96.8        Mkt&Fin  55.50      Placed  425000.000000
# ...      ...      ...            ...    ...         ...            ...
# 211       No     91.0        Mkt&Fin  74.49      Placed  400000.000000
# 212       No     74.0        Mkt&Fin  53.62      Placed  275000.000000
# 213      Yes     59.0        Mkt&Fin  69.72      Placed  295000.000000
# 214       No     70.0         Mkt&HR  60.23      Placed  204000.000000
# 215       No     89.0         Mkt&HR  60.22  Not Placed  288655.405405
#
# [215 rows x 14 columns]

# %% [markdown]
# ## EDA

# %%
sn.countplot(df['status'],palette='plasma')
# Out:
# C:\Users\Tanmay Paul\AppData\Local\Temp\ipykernel_5368\4013246056.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(df['status'],palette='plasma')
# <Axes: xlabel='count', ylabel='status'>

# %%
def valuecount(col):

    return dict(df[col].value_counts())

def getcountplot(col):

    sn.countplot(df[col],palette='plasma')
    plt.xticks(rotation = 'vertical',fontweight = 'bold',fontsize = '10')
    plt.yticks(rotation = 'vertical',fontweight = 'bold',fontsize = '10')
    plt.show()


for col in catvars:
    print(f'Count Plot for feature {col} is shown ↓')
    getcountplot(col)
    print('='*75)

# %%
getfinaldict = {}
for col in catvars:
    getfinaldict[col] = valuecount(col)

getfinaldict
# Out:
# {}

# %%
# top science students placed

df[(df['degree_t']=='Sci&Tech')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  degree_t  \
# 0    151      M  71.00  Central  58.66  Central  Science     58.00  Sci&Tech
# 1    175      M  73.24   Others  50.83   Others  Science     64.27  Sci&Tech
# 2    164      M  63.00   Others  67.00   Others  Science     64.00  Sci&Tech
# 3     78      M  64.00   Others  80.00   Others  Science     65.00  Sci&Tech
# 4     54      M  80.00   Others  70.00   Others  Science     72.00  Sci&Tech
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0    Yes     56.0        Mkt&Fin  61.30  Placed  690000.0
# 1    Yes     64.0        Mkt&Fin  66.23  Placed  500000.0
# 2     No     75.0        Mkt&Fin  66.46  Placed  500000.0
# 3    Yes     69.0        Mkt&Fin  57.65  Placed  500000.0
# 4     No     87.0         Mkt&HR  71.04  Placed  450000.0

# %%
# top Comm&Mgt students placed

df[(df['degree_t']=='Comm&Mgmt')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    120      M  60.80  Central  68.40  Central  Commerce      64.6
# 1    178      F  73.00  Central  97.00   Others  Commerce      79.0
# 2      5      M  85.80  Central  73.60  Central  Commerce      73.3
# 3     96      M  73.00  Central  78.00   Others  Commerce      65.0
# 4     86      F  83.84   Others  89.83   Others  Commerce      77.2
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 1  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0
# 2  Comm&Mgmt     No    96.80        Mkt&Fin  55.50  Placed  425000.0
# 3  Comm&Mgmt    Yes    95.46        Mkt&Fin  62.16  Placed  420000.0
# 4  Comm&Mgmt    Yes    78.74        Mkt&Fin  76.18  Placed  400000.0

# %%
# top Others students placed

df[(df['degree_t']=='Others')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p degree_t  \
# 0    132      F   74.9   Others   57.0   Others  Science     62.00   Others
# 1    194      F   60.0  Central   63.0  Central     Arts     56.00   Others
# 2    186      F   88.0  Central   72.0  Central  Science     78.00   Others
# 3    125      M   67.0  Central   71.0  Central  Science     64.33   Others
# 4    149      F   77.0  Central   86.0  Central     Arts     56.00   Others
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0    Yes     80.0        Mkt&Fin  60.78  Placed  360000.0
# 1    Yes     80.0         Mkt&HR  56.63  Placed  300000.0
# 2     No     82.0         Mkt&HR  71.43  Placed  252000.0
# 3    Yes     64.0         Mkt&HR  61.26  Placed  250000.0
# 4     No     57.0        Mkt&Fin  64.08  Placed  240000.0

# %%
# df['degree_t'].value_counts()

# %%
# max and min salary
# observation : max salary : 9,40,000 and min salary : 2,00,000

df[(df['salary']==max(df['salary'])) | (df['salary']==min(df['salary']))]
# Out:
#       gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# sl_no
# 2          M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 16         F  65.00  Central  75.00  Central  Commerce     69.00  Comm&Mgmt
# 45         F  77.00   Others  73.00   Others  Commerce     81.00  Comm&Mgmt
# 51         F  75.20  Central  73.20  Central   Science     68.40  Comm&Mgmt
# 108        M  82.00   Others  90.00   Others  Commerce     83.00  Comm&Mgmt
# 120        M  60.80  Central  68.40  Central  Commerce     64.60  Comm&Mgmt
# 136        F  72.00  Central  56.00   Others   Science     69.00  Comm&Mgmt
#
#       workex  etest_p specialisation  mba_p  status    salary
# sl_no
# 2        Yes    86.50        Mkt&Fin  66.28  Placed  200000.0
# 16       Yes    72.00        Mkt&Fin  64.66  Placed  200000.0
# 45       Yes    89.00        Mkt&Fin  69.70  Placed  200000.0
# 51        No    65.00         Mkt&HR  62.98  Placed  200000.0
# 108       No    80.00         Mkt&HR  73.52  Placed  200000.0
# 120      Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 136       No    55.60         Mkt&HR  65.63  Placed  200000.0

# %%
# students with salary more than avg salary science dept

df[(df['degree_t']=='Sci&Tech')&(df['salary']<df['salary'].mean()) & (df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index()
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0     188      M  78.50  Central  65.50  Central   Science     67.00
# 1     119      M  76.00  Central  80.00  Central   Science     78.00
# 2      70      M  73.00  Central  73.00  Central   Science     66.00
# 3     212      M  58.00   Others  60.00   Others   Science     72.00
# 4      79      M  84.00   Others  90.90   Others   Science     64.50
# 5       1      M  67.00   Others  91.00   Others  Commerce     58.00
# 6      60      M  52.60  Central  65.58   Others   Science     72.11
# 7     143      M  85.00  Central  60.00   Others   Science     73.43
# 8     198      F  83.96   Others  53.00   Others   Science     91.00
# 9     157      M  84.20  Central  69.40  Central   Science     65.00
# 10      8      M  82.00  Central  64.00  Central   Science     66.00
# 11    139      F  82.00   Others  64.00   Others   Science     73.00
# 12    197      M  72.00   Others  63.00   Others   Science     77.50
# 13    122      F  64.00  Central  67.00   Others   Science     69.60
# 14    111      F  69.50  Central  70.00  Central   Science     72.00
# 15    153      F  75.40   Others  60.50  Central   Science     84.00
# 16     63      F  86.50   Others  64.20   Others   Science     67.40
# 17    118      M  77.00   Others  75.00   Others   Science     73.00
# 18    104      M  73.00  Central  78.00  Central   Science     73.00
# 19    203      M  70.00  Central  63.00  Central   Science     66.00
# 20    127      F  79.00   Others  61.00   Others   Science     75.50
# 21     90      F  84.00   Others  75.00   Others   Science     69.00
# 22      2      M  79.33  Central  78.33   Others   Science     77.48
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0   Sci&Tech    Yes    95.00        Mkt&Fin  64.86  Placed  280000.0
# 1   Sci&Tech    Yes    97.00         Mkt&HR  70.48  Placed  276000.0
# 2   Sci&Tech    Yes    70.00        Mkt&Fin  68.07  Placed  275000.0
# 3   Sci&Tech     No    74.00        Mkt&Fin  53.62  Placed  275000.0
# 4   Sci&Tech     No    86.04        Mkt&Fin  59.42  Placed  270000.0
# 5   Sci&Tech     No    55.00         Mkt&HR  58.80  Placed  270000.0
# 6   Sci&Tech     No    57.60        Mkt&Fin  56.66  Placed  265000.0
# 7   Sci&Tech    Yes    60.00        Mkt&Fin  61.29  Placed  260000.0
# 8   Sci&Tech     No    59.32         Mkt&HR  69.71  Placed  260000.0
# 9   Sci&Tech    Yes    80.00         Mkt&HR  52.72  Placed  255000.0
# 10  Sci&Tech    Yes    67.00        Mkt&Fin  62.14  Placed  252000.0
# 11  Sci&Tech    Yes    96.00        Mkt&Fin  71.77  Placed  250000.0
# 12  Sci&Tech    Yes    78.00        Mkt&Fin  54.48  Placed  250000.0
# 13  Sci&Tech    Yes    55.67         Mkt&HR  71.49  Placed  250000.0
# 14  Sci&Tech     No    57.20         Mkt&HR  54.80  Placed  250000.0
# 15  Sci&Tech     No    98.00        Mkt&Fin  65.25  Placed  240000.0
# 16  Sci&Tech     No    59.00        Mkt&Fin  59.69  Placed  240000.0
# 17  Sci&Tech     No    80.00        Mkt&Fin  67.05  Placed  240000.0
# 18  Sci&Tech    Yes    85.00         Mkt&HR  65.83  Placed  240000.0
# 19  Sci&Tech     No    61.28         Mkt&HR  60.11  Placed  240000.0
# 20  Sci&Tech    Yes    70.00        Mkt&Fin  68.20  Placed  210000.0
# 21  Sci&Tech    Yes    62.00         Mkt&HR  62.36  Placed  210000.0
# 22  Sci&Tech    Yes    86.50        Mkt&Fin  66.28  Placed  200000.0

# %%
# students with salary more than avg salary Comm&Mgmt dept

df[(df['degree_t']=='Comm&Mgmt')&(df['salary']<df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index()
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        7      F   46.0   Others   49.2   Others  Commerce      79.0
# 1       19      F   63.0  Central   66.0  Central  Commerce      64.0
# 2       10      M   58.0  Central   70.0  Central  Commerce      61.0
# 3       15      M   62.0  Central   47.0  Central  Commerce      50.0
# 4       13      F   47.0  Central   55.0   Others   Science      65.0
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 108     16      F   65.0  Central   75.0  Central  Commerce      69.0
# 109     45      F   77.0   Others   73.0   Others  Commerce      81.0
# 110     51      F   75.2  Central   73.2  Central   Science      68.4
# 111    136      F   72.0  Central   56.0   Others   Science      69.0
# 112    108      M   82.0   Others   90.0   Others  Commerce      83.0
#
#       degree_t workex  etest_p specialisation  mba_p      status  \
# 0    Comm&Mgmt     No    74.28        Mkt&Fin  53.29  Not Placed
# 1    Comm&Mgmt     No    68.00         Mkt&HR  64.08  Not Placed
# 2    Comm&Mgmt     No    54.00        Mkt&Fin  52.21  Not Placed
# 3    Comm&Mgmt     No    76.00         Mkt&HR  54.96  Not Placed
# 4    Comm&Mgmt     No    62.00         Mkt&HR  65.04  Not Placed
# ..         ...    ...      ...            ...    ...         ...
# 108  Comm&Mgmt    Yes    72.00        Mkt&Fin  64.66      Placed
# 109  Comm&Mgmt    Yes    89.00        Mkt&Fin  69.70      Placed
# 110  Comm&Mgmt     No    65.00         Mkt&HR  62.98      Placed
# 111  Comm&Mgmt     No    55.60         Mkt&HR  65.63      Placed
# 112  Comm&Mgmt     No    80.00         Mkt&HR  73.52      Placed
#
#             salary
# 0    288655.405405
# 1    288655.405405
# 2    288655.405405
# 3    288655.405405
# 4    288655.405405
# ..             ...
# 108  200000.000000
# 109  200000.000000
# 110  200000.000000
# 111  200000.000000
# 112  200000.000000
#
# [113 rows x 15 columns]

# %%
# maximum students placed are from comm&mgt

df.groupby(['degree_t'])['status'].count().plot(kind = 'bar',color = 'magenta')
# Out:
# <Axes: xlabel='degree_t'>

# %%
# Marketing and Finance specialisation are placed more

df.groupby(['specialisation'])['status'].count().plot(kind = 'bar',color = 'magenta')
# Out:
# <Axes: xlabel='specialisation'>

# %%
# females placed 35% and males 65%

df.groupby(['gender'])['status'].count().plot(kind = 'pie',autopct='%1.0f%%')
# Out:
# <Axes: >

# %%
# max female salary ~ 6,50,000

temp = df[df['gender']=='F']
temp[temp['salary']==max(temp['salary'])].style.background_gradient(cmap = 'plasma')
# Out:
# <style type="text/css">
# #T_3665d_row0_col1, #T_3665d_row0_col3, #T_3665d_row0_col6, #T_3665d_row0_col9, #T_3665d_row0_col11, #T_3665d_row0_col13 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3665d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3665d_level0_col0" class="col_heading level0 col0" >gender</th>
#       <th id="T_3665d_level0_col1" class="col_heading level0 col1" >ssc_p</th>
#       <th id="T_3665d_level0_col2" class="col_heading level0 col2" >ssc_b</th>
#       <th id="T_3665d_level0_col3" class="col_heading level0 col3" >hsc_p</th>
#       <th id="T_3665d_level0_col4" class="col_heading level0 col4" >hsc_b</th>
#       <th id="T_3665d_level0_col5" class="col_heading level0 col5" >hsc_s</th>
#       <th id="T_3665d_level0_col6" class="col_heading level0 col6" >degree_p</th>
#       <th id="T_3665d_level0_col7" class="col_heading level0 col7" >degree_t</th>
#       <th id="T_3665d_level0_col8" class="col_heading level0 col8" >workex</th>
#       <th id="T_3665d_level0_col9" class="col_heading level0 col9" >etest_p</th>
#       <th id="T_3665d_level0_col10" class="col_heading level0 col10" >specialisation</th>
#       <th id="T_3665d_level0_col11" class="col_heading level0 col11" >mba_p</th>
#       <th id="T_3665d_level0_col12" class="col_heading level0 col12" >status</th>
#       <th id="T_3665d_level0_col13" class="col_heading level0 col13" >salary</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sl_no</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3665d_level0_row0" class="row_heading level0 row0" >178</th>
#       <td id="T_3665d_row0_col0" class="data row0 col0" >F</td>
#       <td id="T_3665d_row0_col1" class="data row0 col1" >73.000000</td>
#       <td id="T_3665d_row0_col2" class="data row0 col2" >Central</td>
#       <td id="T_3665d_row0_col3" class="data row0 col3" >97.000000</td>
#       <td id="T_3665d_row0_col4" class="data row0 col4" >Others</td>
#       <td id="T_3665d_row0_col5" class="data row0 col5" >Commerce</td>
#       <td id="T_3665d_row0_col6" class="data row0 col6" >79.000000</td>
#       <td id="T_3665d_row0_col7" class="data row0 col7" >Comm&Mgmt</td>
#       <td id="T_3665d_row0_col8" class="data row0 col8" >Yes</td>
#       <td id="T_3665d_row0_col9" class="data row0 col9" >89.000000</td>
#       <td id="T_3665d_row0_col10" class="data row0 col10" >Mkt&Fin</td>
#       <td id="T_3665d_row0_col11" class="data row0 col11" >70.810000</td>
#       <td id="T_3665d_row0_col12" class="data row0 col12" >Placed</td>
#       <td id="T_3665d_row0_col13" class="data row0 col13" >650000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# max female salary ~ 6,50,000

temp = df[df['gender']=='F']
temp[temp['salary']==min(temp['salary'])].style.background_gradient(cmap = 'plasma')
# Out:
# <style type="text/css">
# #T_4776d_row0_col1, #T_4776d_row0_col13, #T_4776d_row1_col13, #T_4776d_row2_col6, #T_4776d_row2_col11, #T_4776d_row2_col13, #T_4776d_row3_col3, #T_4776d_row3_col9, #T_4776d_row3_col13 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_4776d_row0_col3, #T_4776d_row1_col1, #T_4776d_row1_col6, #T_4776d_row1_col9, #T_4776d_row1_col11 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_4776d_row0_col6, #T_4776d_row3_col6 {
#   background-color: #2a0593;
#   color: #f1f1f1;
# }
# #T_4776d_row0_col9 {
#   background-color: #c9447a;
#   color: #f1f1f1;
# }
# #T_4776d_row0_col11 {
#   background-color: #7d03a8;
#   color: #f1f1f1;
# }
# #T_4776d_row1_col3 {
#   background-color: #fccd25;
#   color: #000000;
# }
# #T_4776d_row2_col1 {
#   background-color: #feba2c;
#   color: #000000;
# }
# #T_4776d_row2_col3 {
#   background-color: #fcd025;
#   color: #000000;
# }
# #T_4776d_row2_col9 {
#   background-color: #8a09a5;
#   color: #f1f1f1;
# }
# #T_4776d_row3_col1 {
#   background-color: #de5f65;
#   color: #f1f1f1;
# }
# #T_4776d_row3_col11 {
#   background-color: #ae2892;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4776d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4776d_level0_col0" class="col_heading level0 col0" >gender</th>
#       <th id="T_4776d_level0_col1" class="col_heading level0 col1" >ssc_p</th>
#       <th id="T_4776d_level0_col2" class="col_heading level0 col2" >ssc_b</th>
#       <th id="T_4776d_level0_col3" class="col_heading level0 col3" >hsc_p</th>
#       <th id="T_4776d_level0_col4" class="col_heading level0 col4" >hsc_b</th>
#       <th id="T_4776d_level0_col5" class="col_heading level0 col5" >hsc_s</th>
#       <th id="T_4776d_level0_col6" class="col_heading level0 col6" >degree_p</th>
#       <th id="T_4776d_level0_col7" class="col_heading level0 col7" >degree_t</th>
#       <th id="T_4776d_level0_col8" class="col_heading level0 col8" >workex</th>
#       <th id="T_4776d_level0_col9" class="col_heading level0 col9" >etest_p</th>
#       <th id="T_4776d_level0_col10" class="col_heading level0 col10" >specialisation</th>
#       <th id="T_4776d_level0_col11" class="col_heading level0 col11" >mba_p</th>
#       <th id="T_4776d_level0_col12" class="col_heading level0 col12" >status</th>
#       <th id="T_4776d_level0_col13" class="col_heading level0 col13" >salary</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sl_no</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4776d_level0_row0" class="row_heading level0 row0" >16</th>
#       <td id="T_4776d_row0_col0" class="data row0 col0" >F</td>
#       <td id="T_4776d_row0_col1" class="data row0 col1" >65.000000</td>
#       <td id="T_4776d_row0_col2" class="data row0 col2" >Central</td>
#       <td id="T_4776d_row0_col3" class="data row0 col3" >75.000000</td>
#       <td id="T_4776d_row0_col4" class="data row0 col4" >Central</td>
#       <td id="T_4776d_row0_col5" class="data row0 col5" >Commerce</td>
#       <td id="T_4776d_row0_col6" class="data row0 col6" >69.000000</td>
#       <td id="T_4776d_row0_col7" class="data row0 col7" >Comm&Mgmt</td>
#       <td id="T_4776d_row0_col8" class="data row0 col8" >Yes</td>
#       <td id="T_4776d_row0_col9" class="data row0 col9" >72.000000</td>
#       <td id="T_4776d_row0_col10" class="data row0 col10" >Mkt&Fin</td>
#       <td id="T_4776d_row0_col11" class="data row0 col11" >64.660000</td>
#       <td id="T_4776d_row0_col12" class="data row0 col12" >Placed</td>
#       <td id="T_4776d_row0_col13" class="data row0 col13" >200000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4776d_level0_row1" class="row_heading level0 row1" >45</th>
#       <td id="T_4776d_row1_col0" class="data row1 col0" >F</td>
#       <td id="T_4776d_row1_col1" class="data row1 col1" >77.000000</td>
#       <td id="T_4776d_row1_col2" class="data row1 col2" >Others</td>
#       <td id="T_4776d_row1_col3" class="data row1 col3" >73.000000</td>
#       <td id="T_4776d_row1_col4" class="data row1 col4" >Others</td>
#       <td id="T_4776d_row1_col5" class="data row1 col5" >Commerce</td>
#       <td id="T_4776d_row1_col6" class="data row1 col6" >81.000000</td>
#       <td id="T_4776d_row1_col7" class="data row1 col7" >Comm&Mgmt</td>
#       <td id="T_4776d_row1_col8" class="data row1 col8" >Yes</td>
#       <td id="T_4776d_row1_col9" class="data row1 col9" >89.000000</td>
#       <td id="T_4776d_row1_col10" class="data row1 col10" >Mkt&Fin</td>
#       <td id="T_4776d_row1_col11" class="data row1 col11" >69.700000</td>
#       <td id="T_4776d_row1_col12" class="data row1 col12" >Placed</td>
#       <td id="T_4776d_row1_col13" class="data row1 col13" >200000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4776d_level0_row2" class="row_heading level0 row2" >51</th>
#       <td id="T_4776d_row2_col0" class="data row2 col0" >F</td>
#       <td id="T_4776d_row2_col1" class="data row2 col1" >75.200000</td>
#       <td id="T_4776d_row2_col2" class="data row2 col2" >Central</td>
#       <td id="T_4776d_row2_col3" class="data row2 col3" >73.200000</td>
#       <td id="T_4776d_row2_col4" class="data row2 col4" >Central</td>
#       <td id="T_4776d_row2_col5" class="data row2 col5" >Science</td>
#       <td id="T_4776d_row2_col6" class="data row2 col6" >68.400000</td>
#       <td id="T_4776d_row2_col7" class="data row2 col7" >Comm&Mgmt</td>
#       <td id="T_4776d_row2_col8" class="data row2 col8" >No</td>
#       <td id="T_4776d_row2_col9" class="data row2 col9" >65.000000</td>
#       <td id="T_4776d_row2_col10" class="data row2 col10" >Mkt&HR</td>
#       <td id="T_4776d_row2_col11" class="data row2 col11" >62.980000</td>
#       <td id="T_4776d_row2_col12" class="data row2 col12" >Placed</td>
#       <td id="T_4776d_row2_col13" class="data row2 col13" >200000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4776d_level0_row3" class="row_heading level0 row3" >136</th>
#       <td id="T_4776d_row3_col0" class="data row3 col0" >F</td>
#       <td id="T_4776d_row3_col1" class="data row3 col1" >72.000000</td>
#       <td id="T_4776d_row3_col2" class="data row3 col2" >Central</td>
#       <td id="T_4776d_row3_col3" class="data row3 col3" >56.000000</td>
#       <td id="T_4776d_row3_col4" class="data row3 col4" >Others</td>
#       <td id="T_4776d_row3_col5" class="data row3 col5" >Science</td>
#       <td id="T_4776d_row3_col6" class="data row3 col6" >69.000000</td>
#       <td id="T_4776d_row3_col7" class="data row3 col7" >Comm&Mgmt</td>
#       <td id="T_4776d_row3_col8" class="data row3 col8" >No</td>
#       <td id="T_4776d_row3_col9" class="data row3 col9" >55.600000</td>
#       <td id="T_4776d_row3_col10" class="data row3 col10" >Mkt&HR</td>
#       <td id="T_4776d_row3_col11" class="data row3 col11" >65.630000</td>
#       <td id="T_4776d_row3_col12" class="data row3 col12" >Placed</td>
#       <td id="T_4776d_row3_col13" class="data row3 col13" >200000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.groupby(['hsc_s'])['status'].count().plot(kind = 'pie',autopct='%1.0f%%',figsize=(15,7))
# Out:
# <Axes: >

# %%
df.head()
# Out:
#       gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# sl_no
# 1          M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 2          M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 3          M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4          M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 5          M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#       workex  etest_p specialisation  mba_p      status         salary
# sl_no
# 1         No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 2        Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 3         No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 4         No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 5         No     96.8        Mkt&Fin  55.50      Placed  425000.000000

# %%
getfinaldict
# Out:
# {}

# %%
print(len(getfinaldict.get('status',[]))),
print(len(getfinaldict.get('degree_t',[])))
# Out:
# 0
# 0

# %%
boolcols = [key for key,value in getfinaldict.items() if len(getfinaldict[key])==2]
tripcols = [key for key in list(getfinaldict.keys()) if key not in boolcols]

print(boolcols,tripcols)
# Out:
# [] []

# %% [markdown]
#  ## Label Encoding process

# %%
def labelencode(le,col):

    df[col] = le.fit_transform(df[col])


getmappings = {}
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in list(getfinaldict.keys()):
    labelencode(le,col)
    getmappings[col] = dict(zip(le.classes_,le.transform(le.classes_)))


df.head()
# Out:
#       gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# sl_no
# 1          M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 2          M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 3          M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4          M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 5          M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#       workex  etest_p specialisation  mba_p      status         salary
# sl_no
# 1         No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 2        Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 3         No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 4         No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 5         No     96.8        Mkt&Fin  55.50      Placed  425000.000000

# %%
# this was the internal mapping structure followed by label encoder for mapping

getmappings
# Out:
# {}

# %%
# removing unwated columns

# df = df.drop(['sl_no'],axis=1)
# df.head(2)

# %% [markdown]
# ## Numerical Columns EDA

# %%
numvars[:]
# Out:
# ['gender',
#  'ssc_p',
#  'ssc_b',
#  'hsc_p',
#  'hsc_b',
#  'hsc_s',
#  'degree_p',
#  'degree_t',
#  'workex',
#  'etest_p',
#  'specialisation',
#  'mba_p',
#  'status',
#  'salary']

# %%
import scipy.stats as stats

def getplots(df,col):

    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color='magenta')

    plt.subplot(1,3,2)
    stats.probplot(df[col],dist='norm',plot=plt)

    plt.subplot(1,3,3)
    sn.boxplot(df[col],color='magenta')

    plt.show()


for col in numvars[:]:
    print(f'Distribution plots for col : {col} are shown ↓')
    getplots(df,col)
    print('='*10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 18
#      13     sn.boxplot(df[col],color='magenta')
#      15     plt.show()
# ---> 18 for col in numvars[:]:
#      19     print(f'Distribution plots for col : {col} are shown ↓')
#      20     getplots(df,col)
#
# NameError: name 'numvars' is not defined

# %% [markdown]
# # Feature Selection

# %%
df.corr(numeric_only=True,
method= "spearman")
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.490028  0.550469  0.270336  0.398587 -0.038574
# hsc_p     0.490028  1.000000  0.433140  0.214212  0.317190 -0.056405
# degree_p  0.550469  0.433140  1.000000  0.198741  0.379493 -0.137430
# etest_p   0.270336  0.214212  0.198741  1.000000  0.216701  0.187516
# mba_p     0.398587  0.317190  0.379493  0.216701  1.000000  0.142070
# salary   -0.038574 -0.056405 -0.137430  0.187516  0.142070  1.000000

# %%
# checking for tightly correlated features

plt.figure(figsize=(15,7))
sn.heatmap(df.corr(numeric_only=True),annot=True,cmap='plasma')
# Out:
# <Axes: >
